# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Social_Network_Ads.csv")
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
X=data.iloc[:,2:4].values# only require age and salary to predict output :all row 2,4 means columns from 2 to 4 .values convert to array

# %%
X.shape
# Out:
# (400, 2)

# %%
Y=data.iloc[:,-1].values #take all rows but only last column

# %%
Y.shape
# Out:
# (400,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
X_test.shape
# Out:
# (80, 2)

# %%
X_train.shape
# Out:
# (320, 2)

# %%
#since square of distance between age is very large from  estimated salary 
#.fit is used to train a ml model 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Scale training data
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.152949  , -0.21876649],
#        [-1.66764704,  0.20404364],
#        [-0.43695488, -0.49057301],
#        [ 2.11909806, -0.76237952],
#        [-1.09963527,  0.41544871],
#        [-0.24761763,  1.23086825],
#        [ 0.41506276,  0.23424436],
#        [-1.47830978, -0.12816432],
#        [ 0.13105688,  2.01608707],
#        [-0.05828037,  0.29464581],
#        [-1.09963527, -0.7321788 ],
#        [ 0.79373727, -0.24896722],
#        [-0.53162351, -1.48719689],
#        [-1.76231567, -1.27579182],
#        [-1.76231567, -1.2455911 ],
#        [-0.62629214, -1.57779906],
#        [-1.28897253, -0.36977011],
#        [-1.00496665, -0.27916794],
#        [-1.76231567,  0.08324074],
#        [-1.09963527, -1.51739761],
#        [-1.57297841,  0.0228393 ],
#        [ 1.07774315,  0.62685377],
#        [-1.76231567, -1.45699617],
#        [ 1.83509217,  0.20404364],
#        [-1.38364116, -0.03756215],
#        [-1.1943039 ,  0.35504726],
#        [-0.152949  , -0.12816432],
#        [ 0.13105688,  1.65367838],
#        [ 1.07774315,  0.56645233],
#        [-0.05828037,  0.14364219],
#        [-0.62629214,  0.0228393 ],
#        [-0.91029802,  0.35504726],
#        [-1.09963527, -1.54759834],
#        [-0.53162351,  0.98926246],
#        [-1.47830978,  0.41544871],
#        [ 0.98307453, -1.15498893],
#        [ 2.02442943,  0.62685377],
#        [ 2.11909806, -0.64157663],
#        [ 0.8884059 ,  2.3180943 ],
#        [-0.24761763, -1.27579182],
#        [ 0.22572551, -0.30936866],
#        [ 1.55108629, -1.2455911 ],
#        [-0.81562939,  0.23424436],
#        [-0.81562939,  0.47585015],
#        [-0.152949  , -0.46037228],
#        [-1.09963527, -1.57779906],
#        [-0.05828037,  0.32484654],
#        [-0.24761763, -0.52077373],
#        [ 0.22572551, -0.30936866],
#        [ 0.79373727, -1.18518965],
#        [-0.05828037, -1.03418603],
#        [ 1.83509217, -1.03418603],
#        [ 1.36174904, -1.39659472],
#        [ 0.41506276,  2.46909792],
#        [ 0.03638825, -0.36977011],
#        [ 0.98307453, -1.12478821],
#        [-0.91029802, -1.06438676],
#        [-1.57297841,  0.62685377],
#        [-1.00496665,  0.68725522],
#        [-0.24761763,  0.89866029],
#        [ 0.69906865,  0.35504726],
#        [ 1.45641766,  0.44564943],
#        [ 1.83509217, -0.21876649],
#        [-1.38364116, -1.18518965],
#        [ 1.07774315, -0.06776287],
#        [ 1.64575492,  1.89528417],
#        [ 1.36174904, -0.88318242],
#        [-0.81562939,  0.47585015],
#        [-0.62629214, -1.00398531],
#        [-0.152949  ,  0.23424436],
#        [ 1.45641766, -1.00398531],
#        [-1.38364116, -1.42679544],
#        [-1.47830978, -1.48719689],
#        [-1.00496665,  2.10668924],
#        [ 0.41506276, -0.39997084],
#        [-0.81562939, -0.18856577],
#        [-1.09963527,  0.50605088],
#        [-0.05828037,  0.20404364],
#        [ 0.69906865, -0.67177735],
#        [-0.81562939, -0.6113759 ],
#        [ 0.13105688,  0.35504726],
#        [-0.91029802,  0.59665305],
#        [-0.05828037, -0.15836505],
#        [ 0.03638825, -0.52077373],
#        [ 0.79373727,  1.50267476],
#        [ 2.02442943,  0.47585015],
#        [ 1.36174904,  2.13688996],
#        [-0.34228626,  1.44227331],
#        [-1.85698429,  0.56645233],
#        [-1.66764704,  0.44564943],
#        [ 0.8884059 , -1.27579182],
#        [ 0.32039414, -0.46037228],
#        [ 0.03638825, -0.52077373],
#        [-0.81562939, -0.7321788 ],
#        [ 1.55108629,  0.08324074],
#        [ 0.32039414, -0.67177735],
#        [-0.91029802,  0.5362516 ],
#        [ 0.8884059 , -0.55097445],
#        [-0.91029802, -0.91338314],
#        [-1.00496665,  0.86845956],
#        [ 1.83509217, -1.2455911 ],
#        [ 1.45641766,  1.11006535],
#        [ 0.32039414, -0.24896722],
#        [-0.91029802, -0.36977011],
#        [ 0.03638825, -0.24896722],
#        [-0.152949  ,  0.95906173],
#        [ 0.13105688, -0.76237952],
#        [-1.09963527,  0.56645233],
#        [ 0.98307453,  1.92548489],
#        [ 0.32039414, -0.12816432],
#        [-0.91029802, -0.24896722],
#        [-0.24761763,  0.14364219],
#        [ 1.26708041, -1.33619327],
#        [ 0.22572551, -0.18856577],
#        [ 0.69906865, -1.366394  ],
#        [ 2.11909806,  1.04966391],
#        [ 0.03638825,  1.35167114],
#        [ 0.32039414, -1.12478821],
#        [ 0.03638825,  0.11344147],
#        [ 0.13105688,  1.1704668 ],
#        [ 1.55108629,  1.23086825],
#        [ 0.8884059 , -1.12478821],
#        [-1.28897253, -1.45699617],
#        [-0.152949  , -0.39997084],
#        [-0.72096077, -1.51739761],
#        [-1.38364116, -0.58117518],
#        [ 0.98307453, -0.79258024],
#        [ 0.8884059 ,  1.14026608],
#        [-0.152949  ,  1.53287549],
#        [-0.05828037, -0.43017156],
#        [-0.34228626,  0.14364219],
#        [ 1.9297608 , -0.88318242],
#        [-0.34228626, -1.27579182],
#        [ 0.79373727, -1.366394  ],
#        [-0.91029802, -0.24896722],
#        [-1.28897253,  0.6570545 ],
#        [ 0.32039414, -0.46037228],
#        [ 0.13105688,  0.29464581],
#        [-1.47830978, -1.21539038],
#        [-0.05828037,  0.23424436],
#        [-0.24761763,  2.40869648],
#        [ 2.02442943,  0.26444509],
#        [-0.43695488, -1.09458748],
#        [-0.05828037,  0.08324074],
#        [-0.24761763, -1.21539038],
#        [-1.28897253, -1.21539038],
#        [-1.1943039 ,  0.68725522],
#        [-1.09963527, -0.97378459],
#        [ 0.22572551,  0.11344147],
#        [-1.00496665, -1.09458748],
#        [ 0.41506276,  0.08324074],
#        [-0.81562939,  0.38524798],
#        [-0.53162351,  1.50267476],
#        [-0.05828037,  0.77785739],
#        [ 1.17241178, -1.42679544],
#        [ 0.41506276,  0.68725522],
#        [ 1.9297608 , -0.6113759 ],
#        [ 1.74042355, -0.21876649],
#        [-1.57297841, -1.54759834],
#        [ 0.60440002,  2.16709068],
#        [-1.38364116,  0.44564943],
#        [ 1.64575492, -0.85298169],
#        [-0.152949  , -0.52077373],
#        [-1.00496665, -0.27916794],
#        [-1.28897253, -0.27916794],
#        [ 2.02442943, -0.76237952],
#        [-0.24761763, -0.88318242],
#        [ 0.60440002, -0.85298169],
#        [ 0.41506276,  1.23086825],
#        [ 1.07774315,  0.20404364],
#        [-0.91029802,  0.50605088],
#        [ 0.98307453,  2.01608707],
#        [-1.66764704,  0.44564943],
#        [-0.43695488,  0.05304002],
#        [-1.00496665, -0.30936866],
#        [-0.152949  ,  2.3180943 ],
#        [-1.09963527, -1.57779906],
#        [ 0.03638825, -0.18856577],
#        [ 0.03638825, -0.49057301],
#        [ 1.07774315,  0.6570545 ],
#        [-0.43695488,  1.38187187],
#        [ 0.03638825,  0.11344147],
#        [ 1.9297608 ,  1.01946318],
#        [ 1.36174904,  1.41207259],
#        [-0.62629214, -1.48719689],
#        [ 0.03638825,  1.38187187],
#        [-1.85698429, -0.70197807],
#        [ 0.69906865, -1.2455911 ],
#        [ 1.74042355,  1.11006535],
#        [-0.24761763,  0.23424436],
#        [-0.43695488, -0.7321788 ],
#        [-1.1943039 , -1.03418603],
#        [ 0.22572551, -0.21876649],
#        [ 0.13105688,  0.17384292],
#        [ 0.98307453,  2.22749213],
#        [ 1.74042355,  1.98588634],
#        [ 1.17241178, -0.70197807],
#        [ 1.26708041,  2.37849575],
#        [-0.81562939,  2.4388972 ],
#        [-0.72096077, -0.55097445],
#        [-1.09963527, -0.46037228],
#        [-0.24761763,  0.71745594],
#        [-1.1943039 ,  0.38524798],
#        [ 0.98307453, -1.03418603],
#        [-0.05828037, -0.30936866],
#        [ 0.13105688,  0.11344147],
#        [-0.24761763,  0.14364219],
#        [-0.24761763,  0.11344147],
#        [ 0.32039414, -0.49057301],
#        [-1.28897253, -1.33619327],
#        [ 0.69906865, -1.06438676],
#        [-0.53162351, -1.48719689],
#        [ 2.11909806, -1.00398531],
#        [ 2.11909806,  0.47585015],
#        [ 0.41506276,  0.38524798],
#        [ 0.41506276, -0.43017156],
#        [-1.76231567,  0.26444509],
#        [-1.09963527, -1.06438676],
#        [-0.43695488, -0.21876649],
#        [-1.76231567, -1.39659472],
#        [-0.72096077,  2.04628779],
#        [-0.05828037, -0.46037228],
#        [ 0.8884059 ,  1.20066752],
#        [ 0.32039414, -0.21876649],
#        [-1.85698429,  0.0228393 ],
#        [ 0.41506276,  0.17384292],
#        [-0.24761763, -0.30936866],
#        [-1.09963527,  0.38524798],
#        [ 0.41506276,  0.38524798],
#        [ 0.8884059 , -1.00398531],
#        [-1.66764704, -1.33619327],
#        [ 1.45641766,  0.14364219],
#        [-0.91029802,  1.6838791 ],
#        [ 0.79373727, -1.33619327],
#        [-0.81562939, -1.18518965],
#        [-0.24761763,  0.62685377],
#        [-0.24761763, -1.33619327],
#        [ 0.41506276, -0.39997084],
#        [-0.34228626, -0.7321788 ],
#        [-0.24761763, -0.27916794],
#        [ 1.07774315, -1.18518965],
#        [-1.85698429, -0.46037228],
#        [-1.66764704,  0.56645233],
#        [ 0.8884059 , -0.49057301],
#        [-0.91029802,  0.6570545 ],
#        [-1.28897253, -0.36977011],
#        [ 1.45641766,  2.28789358],
#        [ 0.50973139,  1.35167114],
#        [ 0.98307453, -0.97378459],
#        [ 0.32039414,  0.14364219],
#        [ 0.41506276,  1.11006535],
#        [ 0.22572551, -0.06776287],
#        [-0.72096077,  0.38524798],
#        [ 0.50973139,  1.86508345],
#        [ 1.55108629,  1.11006535],
#        [-0.152949  ,  1.74428055],
#        [ 0.41506276, -0.06776287],
#        [-1.09963527,  1.53287549],
#        [-0.152949  , -1.03418603],
#        [ 0.32039414,  0.38524798],
#        [-0.91029802, -0.70197807],
#        [ 0.41506276, -0.06776287],
#        [ 0.41506276,  0.35504726],
#        [-0.05828037,  2.3180943 ],
#        [ 0.8884059 , -1.42679544],
#        [ 1.07774315, -1.18518965],
#        [ 0.79373727, -1.06438676],
#        [ 0.03638825, -0.06776287],
#        [ 0.32039414,  0.14364219],
#        [ 0.13105688, -0.18856577],
#        [ 0.13105688,  0.11344147],
#        [ 0.03638825, -0.18856577],
#        [-0.62629214,  0.11344147],
#        [ 0.22572551, -0.24896722],
#        [-0.72096077, -0.15836505],
#        [-0.24761763, -0.85298169],
#        [ 0.03638825,  0.38524798],
#        [-1.28897253,  0.50605088],
#        [ 0.98307453,  0.68725522],
#        [-1.00496665,  0.50605088],
#        [ 2.11909806, -0.76237952],
#        [ 0.22572551,  0.32484654],
#        [-0.24761763, -1.366394  ],
#        [-0.43695488, -1.18518965],
#        [ 1.36174904,  0.68725522],
#        [-0.62629214, -0.27916794],
#        [ 0.98307453,  1.56307621],
#        [ 0.13105688, -0.76237952],
#        [-1.09963527,  0.14364219],
#        [ 0.79373727,  0.62685377],
#        [-0.72096077,  0.35504726],
#        [ 0.69906865, -1.366394  ],
#        [ 0.13105688, -0.24896722],
#        [ 1.07774315, -0.94358386],
#        [ 0.41506276, -0.0979636 ],
#        [-0.62629214, -0.03756215],
#        [-0.05828037,  0.38524798],
#        [ 0.79373727,  0.44564943],
#        [-0.72096077, -1.57779906],
#        [-0.62629214,  0.6570545 ],
#        [-1.09963527,  0.38524798],
#        [-1.66764704, -0.55097445],
#        [ 0.8884059 ,  1.38187187],
#        [-0.05828037,  0.35504726],
#        [-1.00496665, -1.42679544],
#        [ 0.13105688,  0.23424436],
#        [-0.05828037,  0.11344147],
#        [-1.1943039 ,  0.59665305],
#        [ 0.8884059 , -0.7321788 ],
#        [ 2.11909806,  1.23086825],
#        [-0.05828037,  2.37849575],
#        [ 0.98307453,  0.20404364],
#        [ 0.22572551,  2.25769286],
#        [-0.05828037, -0.36977011],
#        [ 1.17241178, -0.94358386],
#        [-0.43695488,  2.46909792],
#        [ 0.32039414,  0.14364219],
#        [-0.24761763, -0.70197807],
#        [ 1.83509217,  1.65367838],
#        [ 0.69906865,  1.92548489]])

# %%
# Scale test data
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[-0.24761763, -0.36977011],
#        [-0.05828037,  2.10668924],
#        [ 0.98307453, -1.03418603],
#        [ 0.22572551,  1.20066752],
#        [ 0.8884059 , -0.6113759 ],
#        [-0.05828037,  0.38524798],
#        [ 1.36174904,  2.49929865],
#        [-0.24761763, -0.18856577],
#        [ 0.32039414,  0.14364219],
#        [-0.53162351,  1.59327693],
#        [-0.24761763, -0.6113759 ],
#        [ 0.79373727,  0.86845956],
#        [ 1.07774315,  2.22749213],
#        [-0.72096077,  1.47247404],
#        [-0.24761763, -0.52077373],
#        [-1.09963527, -1.12478821],
#        [-1.85698429,  0.44564943],
#        [-1.28897253, -1.06438676],
#        [ 2.02442943, -1.15498893],
#        [ 0.22572551,  0.14364219],
#        [-0.34228626,  1.35167114],
#        [-0.53162351,  1.50267476],
#        [-1.66764704, -0.94358386],
#        [-0.72096077,  0.59665305],
#        [ 0.22572551,  0.23424436],
#        [-0.81562939, -0.7321788 ],
#        [-0.34228626, -0.7321788 ],
#        [ 0.13105688,  2.01608707],
#        [-0.24761763,  0.29464581],
#        [ 0.79373727,  0.20404364],
#        [-0.62629214,  0.20404364],
#        [-0.72096077,  1.20066752],
#        [ 0.22572551,  0.23424436],
#        [ 0.8884059 , -1.33619327],
#        [-1.00496665,  0.6570545 ],
#        [ 1.07774315, -0.85298169],
#        [ 1.9297608 ,  0.83825884],
#        [ 1.9297608 , -1.33619327],
#        [ 0.32039414,  0.59665305],
#        [ 0.22572551, -0.30936866],
#        [-0.24761763, -0.43017156],
#        [ 0.98307453,  0.86845956],
#        [ 0.32039414,  0.11344147],
#        [-0.43695488, -0.79258024],
#        [-1.00496665, -1.51739761],
#        [-1.57297841,  0.14364219],
#        [ 0.79373727, -0.79258024],
#        [-0.152949  ,  1.77448128],
#        [ 0.8884059 , -0.52077373],
#        [-0.72096077,  0.6570545 ],
#        [-0.24761763,  0.17384292],
#        [ 0.32039414,  0.35504726],
#        [-0.62629214,  1.53287549],
#        [ 0.22572551, -0.6113759 ],
#        [ 0.98307453,  2.13688996],
#        [-0.62629214,  0.26444509],
#        [ 1.64575492,  1.74428055],
#        [-0.53162351,  0.56645233],
#        [ 1.9297608 ,  2.3180943 ],
#        [-1.00496665,  0.62685377],
#        [-1.00496665, -0.39997084],
#        [-0.24761763, -0.06776287],
#        [-0.24761763,  0.23424436],
#        [-1.76231567,  0.5362516 ],
#        [ 2.02442943,  1.89528417],
#        [-1.47830978, -0.36977011],
#        [-0.53162351,  2.49929865],
#        [-0.24761763, -0.21876649],
#        [ 1.17241178,  0.62685377],
#        [-0.24761763, -1.42679544],
#        [-1.38364116, -0.12816432],
#        [-0.53162351,  2.04628779],
#        [ 0.50973139,  1.98588634],
#        [-1.1943039 , -1.366394  ],
#        [ 0.13105688,  0.86845956],
#        [ 2.02442943,  2.28789358],
#        [-0.24761763, -0.24896722],
#        [-0.24761763,  0.35504726],
#        [ 1.26708041,  2.01608707],
#        [ 0.79373727,  0.35504726]])

# %%
np.sqrt(X_train.shape[0])# 0 becaouse shape return row and column i need only row
# Out:
# np.float64(17.88854381999832)

# %%
k = 17

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=k)

# %%
# Train 
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
y_pred = knn.predict(X_test)

# %%
y_pred.shape
# Out:
# (80,)

# %%
y_test.shape
# Out:
# (80,)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
# other way
accuracy = []
for i in range(1, 26):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    accuracy.append(accuracy_score(y_test, knn.predict(X_test)))

# %%
plt.plot(range(1, 26), accuracy)
plt.xlabel("K value")
plt.ylabel("Accuracy")
plt.title("K vs Accuracy")
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9
